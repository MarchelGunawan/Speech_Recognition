# %%
from pydub import AudioSegment
import numpy as np
from numpy.fft import fft
import matplotlib.pyplot as plt

# %%
a = AudioSegment.from_wav('Marchel Week10.wav')
y = np.array(a.get_array_of_samples())

# %%
len(y)
# Out:
# 605184

# %%
plt.plot(y)
plt.show()

# %%
yf = fft(y)
plt.plot(np.abs(yf))
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.plot(y)

# %%
w = 512
c = len(y)//w
c
# Out:
# 1182

# %%
#data = []
#data.append()
#0-4500 noise
#5000-10000 a rise
#10000-13000 a steady
#13000-47000 a lower
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12514/408370700.py in <module>
#       1 data = []
# ----> 2 data.append()
#       3 #0-4500 noise
#       4 #5000-10000 a rise
#       5 #10000-13000 a steady
#
# TypeError: append() takes exactly one argument (0 given)

# %%
x = 10000
for i in range(7):
    print(x)
    x += 512
# Out:
# 10000
# 10512
# 11024
# 11536
# 12048
# 12560
# 13072

# %%
# noise before a
lb = []
data0 = []
start = 0
stop = w
while True:
    if stop >= 4500:
        stop = 4500
        data0.append(y[start:stop])
        break
    else:
        data0.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#a rise
data1 = []
start = 5000
stop = 5000 + w
while True:
    if stop > 10000:
        stop = 10000
        data1.append(y[start:stop])
        break
    else:
        data1.append(y[start:stop])
    start += w+1
    stop += w
lb.append(1)

# %%
#a steady
data2 = []
start = 10000
stop = 10512
while True:
    if stop > 13000:
        stop = 13000
        data2.append(y[start:stop])
        break
    else:
        data2.append(y[start:stop])
    start += w+1
    stop += w
lb.append(2)

# %%
#a lower or drop
data3 = []
start = 13000
stop = 13000 + w
while True:
    if stop >= 47000:
        stop = 47000
        data3.append(y[start:stop])
        break
    else:
        data3.append(y[start:stop])
    start += w+1
    stop += w
lb.append(3)

# %%
#noise after a or before i
data4 = []
start = 51000
stop = 51000 + w
while True:
    if stop >= 70000:
        stop = 70000
        data4.append(y[start:stop])
        break
    else:
        data4.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#i rise
data5 = []
start = 74000
stop = 74000 + w
while True:
    if stop >= 89000:
        stop = 89000
        data5.append(y[start:stop])
        break
    else:
        data5.append(y[start:stop])
    start += w+1
    stop += w
lb.append(4)

# %%
#i steady
data6 = []
start = 89500
stop = 89500 + w
while True:
    if stop >= 95000:
        stop = 95000
        data6.append(y[start:stop])
        break
    else:
        data6.append(y[start:stop])
    start += w+1
    stop += w
lb.append(5)

# %%
#i lower or drop
data7 = []
start = 100000
stop = 100000 + w
while True:
    if stop >= 110000:
        stop = 110000
        data7.append(y[start:stop])
        break
    else:
        data7.append(y[start:stop])
    start += w+1
    stop += w
lb.append(6)

# %%
#noise after i
data8 = []
start = 125000
stop = 125000 + w
while True:
    if stop >= 138000:
        stop = 138000
        data8.append(y[start:stop])
        break
    else:
        data8.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#u rise
data9 = []
start = 140000
stop = 140000 + w
while True:
    if stop >= 140000:
        stop = 140000
        data9.append(y[start:stop])
        break
    else:
        data9.append(y[start:stop])
    start += w+1
    stop += w
lb.append(7)

# %%
#u steady 145000:170000
data10 = []
start = 145000
stop = 145000 + w
while True:
    if stop >= 145000:
        stop = 145000
        data10.append(y[start:stop])
        break
    else:
        data10.append(y[start:stop])
    start += w+1
    stop += w
lb.append(8)

# %%
# u lower 170000:180000
data11 = []
start = 170000
stop = 170000 + w
while True:
    if stop >= 180000:
        stop = 180000
        data11.append(y[start:stop])
        break
    else:
        data11.append(y[start:stop])
    start += w+1
    stop += w
lb.append(9)

# %%
#noise after u :205000
data12 = []
start = 185000
stop = 185000 + w
while True:
    if stop >= 200000:
        stop = 200000
        data12.append(y[start:stop])
        break
    else:
        data12.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#e raise
data13 = []
start = 207000
stop = 207000 + w
while True:
    if stop >= 210000:
        stop = 210000
        data13.append(y[start:stop])
        break
    else:
        data13.append(y[start:stop])
    start += w+1
    stop += w
lb.append(10)

# %%
#e steady
data14 = []
start = 210000
stop = 210000 + w
while True:
    if stop >= 233000:
        stop = 233000
        data14.append(y[start:stop])
        break
    else:
        data14.append(y[start:stop])
    start += w+1
    stop += w
lb.append(11)

# %%
#e lower 
data15 = []
start = 233000
stop = 233000 + w
while True:
    if stop >= 250000:
        stop = 250000
        data15.append(y[start:stop])
        break
    else:
        data15.append(y[start:stop])
    start += w+1
    stop += w
lb.append(12)

# %%
#noise after e
data16 = []
start = 250000
stop = 250000 + w
while True:
    if stop >= 265000:
        stop = 265000
        data16.append(y[start:stop])
        break
    else:
        data16.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#o rise
data17 = []
start = 268000
stop = 268000 + w
while True:
    if stop >= 274000:
        stop = 274000
        data17.append(y[start:stop])
        break
    else:
        data17.append(y[start:stop])
    start += w+1
    stop += w
lb.append(13)

# %%
#o steady
data18 = []
start = 274000
stop = 274000 + w
while True:
    if stop >= 295000:
        stop = 295000
        data18.append(y[start:stop])
        break
    else:
        data18.append(y[start:stop])
    start += w+1
    stop += w
lb.append(14)

# %%
#o lower
data19 = []
start = 295000
stop = 295000 + w
while True:
    if stop >= 305000:
        stop = 305000
        data19.append(y[start:stop])
        break
    else:
        data19.append(y[start:stop])
    start += w+1
    stop += w
lb.append(15)

# %%
#noise after o
data20 = []
start = 305000
stop = 305000 + w
while True:
    if stop >= 325000:
        stop = 325000
        data20.append(y[start:stop])
        break
    else:
        data20.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
#eu rise
data21 = []
start = 325000
stop = 325000 + w
while True:
    if stop >= 325000:
        stop = 325000
        data20.append(y[start:stop])
        break
    else:
        data20.append(y[start:stop])
    start += w+1
    stop += w
lb.append(0)

# %%
plt.figure(figsize=(20,5))
plt.plot(y[250000:265000])

# %%
lb
# Out:
# [0, 1, 2, 3, 0, 4, 5]

# %%
plt.plot(y[0:4500]) #noise before a

# %%
plt.plot(y[0:50000]) #a

# %%
plt.plot(y[5000:10000]) #a rise

# %%
plt.plot(y[10000:13000]) #a steady

# %%
plt.plot(y[13000:47000]) #a lower

# %%
plt.plot(y[51000:70000]) #noise after a or before i

# %%
plt.plot(y[70000:110000]) #i

# %%
plt.plot(y[74000:89000]) #i rise

# %%
plt.plot(y[89500:95000]) #i steady

# %%
plt.plot(y[100000:110000]) #i lower

# %%
plt.plot(y[140000:180000]) #u

# %%
plt.plot(y[140000:145000]) #u rise

# %%
plt.plot(y[145000:170000]) #u steady

# %%
plt.plot(y[170000:180000]) #u lower

# %%
plt.plot(y[205000:250000]) #e

# %%
plt.plot(y[207000:210000]) #e rise

# %%
plt.plot(y[210000:233000]) #e steady

# %%
plt.plot(y[233000:250000]) #e lower

# %%
plt.plot(y[265000:310000]) #o

# %%
plt.plot(y[268000:274000]) #o rise

# %%
plt.plot(y[274000:295000]) #o steady

# %%
plt.plot(y[295000:305000]) #o lower

# %%
plt.plot(y[325000:360000]) #eu

# %%
plt.plot(y[328000:334000]) #eu rise

# %%
plt.plot(y[334000:350000]) #eu steady

# %%
plt.plot(y[350000:360000]) #eu lower

# %%
plt.plot(y[385000:440000]) #ai

# %%
plt.plot(y[389000:394000]) #ai rise

# %%
plt.plot(y[394000:417000]) #ai steady

# %%
plt.plot(y[417000:430000]) #ai lower

# %%
plt.plot(y[450000:498000]) #oi

# %%
plt.plot(y[453000:462000]) #oi rise

# %%
plt.plot(y[462000:478000]) #oi steady

# %%
plt.plot(y[478000:493000]) #oi lower

# %%
plt.plot(y[510000:565000]) #au

# %%
plt.plot(y[515000:520000]) #au rise

# %%
plt.plot(y[520000:535000]) #au steady

# %%
plt.plot(y[530000:555000]) #au lower

# %%
plt.plot(y[565000:600000]) #ei

# %%
plt.plot(y[570000:575000]) #ei rise

# %%
plt.plot(y[575000:580000]) #ei steady

# %%
plt.plot(y[580000:595000]) #ei lower
