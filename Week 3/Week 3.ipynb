# %%
import numpy as np
from numpy.fft import fft
import pydub
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import bisect
# %matplotlib inline

# %%
song = Path('indonesia_baru(edited).ogg')
a = pydub.AudioSegment.from_ogg(song)
y = np.array(a.get_array_of_samples())

# %%
plt.plot(y)
plt.show()

# %%
yf = fft(y)
plt.plot(np.abs(yf))
plt.show()

# %%
f = []
w = 255
for i in range(round(len(y)/w)-1):
    f.append(y[i*w:(i+1)*w-1])
len(f)
# Out:
# 963

# %%
c=[]
for i in range(len(f)):
    for j in range(len(f)):
        c.append(np.corrcoef(f[i],f[j]))

# %%
data0 = []
for i in range(len(c)):
    for j in range(len(c)):
        if c[i][0][1] > 0 and c[i][0][1] < 0.1:
            data0.append(i,j)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_22283/368676319.py in <module>
#       4     for j in range(len(c)):
#       5         p0.append(np.corrcoef(f[i],f[j]))
# ----> 6         if c[i][0][1] > p0[0][1] and c[i][0][1] < p0[0][1]:
#       7             data0.append(i,j)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(data0)

# %%
data1 = []
for i in range(len(c)):
    if c[i][0][1] > 0.101 and c[i][0][1] < 0.2:
        data1.append(i)

# %%
data2 = []
for i in range(len(c)):
    if c[i][0][1] > 0.201 and c[i][0][1] < 0.3:
        data2.append(i)

# %%
data3 = []
for i in range(len(c)):
    if c[i][0][1] > 0.301 and c[i][0][1] < 0.4:
        data3.append(i)

# %%
data4 = []
for i in range(len(c)):
    if c[i][0][1] > 0.401 and c[i][0][1] < 0.5:
        data4.append(i)

# %%
data5 = []
for i in range(len(c)):
    if c[i][0][1] > 0.501 and c[i][0][1] < 0.6:
        data5.append(i)

# %%
data6 = []
for i in range(len(c)):
    if c[i][0][1] > 0.601 and c[i][0][1] < 0.7:
        data6.append(i)

# %%
data7 = []
for i in range(len(c)):
    if c[i][0][1] > 0.701 and c[i][0][1] < 0.8:
        data7.append(i)

# %%
data8 = []
for i in range(len(c)):
    if c[i][0][1] > 0.801 and c[i][0][1] < 0.9:
        data8.append(i)

# %%
data9 = []
for i in range(len(c)):
    if c[i][0][1] > 0.901 and c[i][0][1] < 1:
        data9.append(i)

# %%
data10 = []
for i in range(len(c)):
    if c[i][0][1] > -0.1 and c[i][0][1] < 0:
        data10.append(i)

# %%
data11 = []
for i in range(len(c)):
    if c[i][0][1] > -0.2 and c[i][0][1] < -0.1:
        data11.append(i)

# %%
data12 = []
for i in range(len(c)):
    if c[i][0][1] > -0.3 and c[i][0][1] < -0.2:
        data12.append(i)

# %%
data13 = []
for i in range(len(c)):
    if c[i][0][1] > -0.4 and c[i][0][1] < -0.3:
        data13.append(i)

# %%
data14 = []
for i in range(len(c)):
    if c[i][0][1] > -0.5 and c[i][0][1] < -0.4:
        data14.append(i)

# %%
data15 = []
for i in range(len(c)):
    if c[i][0][1] > -0.6 and c[i][0][1] < -0.5:
        data15.append(i)

# %%
data16 = []
for i in range(len(c)):
    if c[i][0][1] > -0.7 and c[i][0][1] < -0.6:
        data16.append(i)

# %%
data17 = []
for i in range(len(c)):
    if c[i][0][1] > -0.8 and c[i][0][1] < -0.7:
        data17.append(i)

# %%
data18 = []
for i in range(len(c)):
    if c[i][0][1] > -0.9 and c[i][0][1] < -0.8:
        data18.append(i)

# %%
data19 = []
for i in range(len(c)):
    if c[i][0][1] > -1 and c[i][0][1] < -0.9:
        data19.append(i)

# %%
plt.plot(f[data0[0]])
plt.plot(f[data1[0]])

# %%
plt.plot(f[data2[0]])
plt.plot(f[data3[0]])

# %%
plt.plot(f[data4[0]])
plt.plot(f[data5[0]])
