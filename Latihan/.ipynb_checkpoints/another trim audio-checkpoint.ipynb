# %%
import pydub
from pydub.silence import split_on_silence
import matplotlib.pyplot as plt
from numpy.fft import fft
import numpy as np
import librosa
# %matplotlib inline

# %%
sound= pydub.AudioSegment.from_wav('Test.wav')
x = np.array(song.get_array_of_samples())

# %%
plt.plot(x)
plt.show()

# %%
y, sr = librosa.load("Test.wav", sr = None)

# %%
y_ = librosa.effects.trim(y,frame_length=8000, top_db = 30)[0]

# %%
plt.plot(y_)
plt.show()
